# %%
y.list_scenes()
my_scene = y.scene[0]
first_sample_token= my_scene['first_sample_token']
my_scene
my_sample = y.get('sample', first_sample_token)
my_sample
# Out:
# scene-0061, Parked truck, construction, intersectio... [18-07-24 03:28:47]   19s, singapore-onenorth, #anns:4622
# scene-0103, Many peds right, wait for turning car, ... [18-08-01 19:26:43]   19s, boston-seaport, #anns:2046
# scene-0655, Parking lot, parked cars, jaywalker, be... [18-08-27 15:51:32]   20s, boston-seaport, #anns:2332
# scene-0553, Wait at intersection, bicycle, large tr... [18-08-28 20:48:16]   20s, boston-seaport, #anns:1950
# scene-0757, Arrive at busy intersection, bus, wait ... [18-08-30 19:25:08]   20s, boston-seaport, #anns:592
# scene-0796, Scooter, peds on sidewalk, bus, cars, t... [18-10-02 02:52:24]   20s, singapore-queensto, #anns:708
# scene-0916, Parking lot, bicycle rack, parked bicyc... [18-10-08 07:37:13]   20s, singapore-queensto, #anns:2387
# scene-1077, Night, big street, bus stop, high speed... [18-11-21 11:39:27]   20s, singapore-hollandv, #anns:890
# ...

# %%
import open3d as o3d
import numpy as np
from new import NuScenesExplorer
import matplotlib.pyplot as plt
from nuscenes import NuScenes

y= NuScenes(version ='v1.0-mini',  dataroot='/home/sid/data/sets')
my= NuScenesExplorer(y)
y.render_pointcloud_in_image('ca9a282c9e77460f8360f564131a8af5', pointsensor_channel='LIDAR_TOP', render_intensity= True)
my.map_pointcloud_to_image('9d9bf11fb0e144c8b446d54a8a00184f', 'e3d495d4ac534d54b321f50006683844')
# Out:
# ...
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 0.393 seconds.
# ...
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ...
# (array([[1.32899337e+00, 2.61542884e+00, 3.98248055e+00, ...,
#          1.58025663e+03, 1.58829323e+03, 1.59029333e+03],
#         [2.72383210e+02, 2.35807694e+02, 1.98800442e+02, ...,
#          5.14035373e+02, 4.04123671e+02, 5.14100881e+02],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#          1.00000000e+00, 1.00000000e+00, 1.00000000e+00]]),
#  array([20.19352 , 20.18004 , 20.214766, ..., 62.9002  , 35.586002,
#         62.860847], dtype=float32),
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x900 at 0x7F4C645BA7F0>,
#  {'token': 'a183049901c24361a6b0b11b8013137c',
# ...

# %%
import open3d as o3d
import numpy as np
from new import NuScenesExplorer
import matplotlib.pyplot as plt
from nuscenes import NuScenes

y= NuScenes(version ='v1.0-mini',  dataroot='/home/sid/data/sets')
my= NuScenesExplorer(y)
y.render_pointcloud_in_image('ca9a282c9e77460f8360f564131a8af5', pointsensor_channel='RADAR_FRONT')
my.map_pointcloud_to_image('37091c75b9704e0daa829ba56dfa0906', 'e3d495d4ac534d54b321f50006683844')
# Out:
# ...
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 0.403 seconds.
# ...
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ...
# (array([[1.76668179e+02, 3.60028420e+02, 3.82891813e+02, 1.53875114e+03,
#          4.50797228e+02, 1.42022827e+03, 5.93980140e+02, 3.90849451e+02,
#          1.39925677e+03, 4.86173194e+02, 5.36784322e+02, 3.82701428e+02,
#          4.35656244e+02, 4.84302440e+02, 4.01899450e+01, 1.22333518e+03,
#          1.19822057e+03, 1.16746307e+03, 1.01430322e+03, 1.20457287e+03,
#          4.53011579e+02, 7.52006492e+02, 6.32343009e+02, 8.95012383e+02,
#          7.11814817e+02, 1.47530611e+03, 6.94789183e+02, 1.31632581e+03,
#          2.49379852e+02, 1.09478458e+03, 9.73438675e+02, 6.36465156e+02,
# ...
